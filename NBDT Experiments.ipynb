# %%
import nbdt
import numpy as np
import matplotlib.pyplot as plt

# %%
test0 = plt.imread("airplane.jpeg")

# %%
plt.imshow(test0);

# %%
test0.shape
# Out:
# (2250, 3375, 3)

# %%
test1 = plt.imread('cat.jpeg')
test1.shape
# Out:
# (338, 600, 3)

# %%
from nbdt.model import SoftNBDT
from nbdt.models import ResNet18, wrn28_10_cifar10, wrn28_10_cifar100, wrn28_10  # use wrn28_10 for TinyImagenet200
from torchvision import transforms
from nbdt.utils import DATASET_TO_CLASSES, load_image_from_path, maybe_install_wordnet
from IPython.display import display
# Out:
# not enough values to unpack (expected 2, got 0)

# %%
model = wrn28_10()
model = SoftNBDT(
  pretrained=True,
  dataset='TinyImagenet200',
  arch='wrn28_10',
  model=model)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-1edadf8d502f> in <module>
# ----> 1 model = wrn28_10()
#       2 model = SoftNBDT(
#       3   pretrained=True,
#       4   dataset='TinyImagenet200',
#       5   arch='wrn28_10',
#
# ~/anaconda3/lib/python3.7/site-packages/nbdt/models/wideresnet.py in wrn28_10(pretrained, progress, dataset, **kwargs)
#      25     stage, technically.
#      26     """
# ---> 27     model = get_wrn_cifar(blocks=28, width_factor=10, model_name="wrn28_10", **kwargs)
#      28     model.features.final_pool = nn.AdaptiveAvgPool2d((1, 1))
#      29     model = _wrn('wrn28_10', model, pretrained=pretrained, progress=progress, dataset=dataset)
#
# TypeError: get_wrn_cifar() missing 1 required positional argument: 'num_classes'
